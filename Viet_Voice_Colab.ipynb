# %% [markdown]
# # 🎙️ Viet Voice Studio - Chạy Online 1-Click trên Google Colab
# Nhân bản giọng nói và đọc văn bản Tiếng Việt miễn phí 100% không giới hạn ký tự.
#
# 👉 **Hướng dẫn:** Chỉ cần bấm nút **Play ▶** ở ô code bên dưới để khởi chạy toàn bộ hệ thống!

# %%
# @title 🚀 Bấm Play để khởi động Viet Voice Studio (Kèm link truy cập công khai)
# !git clone https://github.com/luckyluong2k-collab/voice.git
# %cd voice

# !pip install -q -r requirements.txt pyngrok

import os, time, threading
from google.colab.output import eval_js

# Khởi chạy background server
def run_server():
    # !python app.py

threading.Thread(target=run_server, daemon=True).start()
time.sleep(3)

# Hiển thị URL truy cập trực tiếp trên Colab
print("\n" + "="*60)
print("🎉 VIET VOICE STUDIO ĐÃ SẴN SÀNG!")
print("Truy cập tại liên kết dưới đây:")
print(eval_js("google.colab.kernel.proxyPort(7860)"))
print("="*60 + "\n")
